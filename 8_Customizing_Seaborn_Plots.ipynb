# %%
# Import the matplotlib.pyplot, pandas, and numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ddc0ec5-bcb1-47ab-b802-9942049441b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ddc0ec5-bcb1-47ab-b802-9942049441b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving countries-of-the-world.csv to countries-of-the-world (1).csv
# Saving mpg.csv to mpg.csv
# Saving student-alcohol-consumption.csv to student-alcohol-consumption (1).csv
# Saving young-people-survey-responses.csv to young-people-survey-responses (1).csv

# %%
survey_data = pd.read_csv('young-people-survey-responses.csv', index_col=0)
survey_data.head(3)
# Out:
#    Music  Techno  Movies  History  ...   Age  Siblings  Gender  Village - town
# 0    5.0     1.0     5.0      1.0  ...  20.0       1.0  female         village
# 1    4.0     1.0     5.0      1.0  ...  19.0       2.0  female            city
# 2    5.0     1.0     5.0      1.0  ...  20.0       2.0  female            city
#
# [3 rows x 15 columns]

# %%
survey_data["Parents' advice"].describe()
# Out:
# count    1008.000000
# mean        3.265873
# std         0.865736
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Parents' advice, dtype: float64

# %%
conditions = [
    (survey_data["Parents' advice"] <= 1),
    (survey_data["Parents' advice"] <= 2), (survey_data["Parents' advice"] <= 3),
    (survey_data["Parents' advice"]<= 4), (survey_data["Parents' advice"] > 4)
    ]

# %%
values = ['Never', 'Rarely', 'Sometimes', 'Often', 'Always']

# %%
survey_data["Parents advice"] = np.select(conditions, values)
survey_data.head(3)
# Out:
#    Music  Techno  Movies  ...  Gender  Village - town  Parents advice
# 0    5.0     1.0     5.0  ...  female         village           Often
# 1    4.0     1.0     5.0  ...  female            city          Rarely
# 2    5.0     1.0     5.0  ...  female            city       Sometimes
#
# [3 rows x 16 columns]

# %% [markdown]
# ## Changing style and palette
#
# 1. Set the style to "whitegrid" to help the audience determine the number of responses in each category.
# 2. Change the color palette to the diverging palette named "RdBu".
#
# **HINT!**
#
# * Use the sns.set_style() function.
# * Use the sns.set_palette() function.

# %%
# Set the style to "whitegrid"


# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes", 
                  "Often", "Always"]

sns.catplot(x="Parents Advice", 
            data=survey_data, 
            kind="count", 
            order=category_order)

# Show plot
plt.show()

# %% [markdown]
# ## Using a custom palette
#
# 1. Set the style to "darkgrid".
# 2. Set a custom color palette with the hex color codes "#39A7D0" and "#36ADA4".
#
# **HINT!**
#
# * Use sns.set_style() to set the style.
# * The sns.set_palette() function can be given a list of hex color codes to set a custom palette.

# %%
# Set the style to "darkgrid"


# Set a custom color palette


# Create the box plot of age distribution by gender
sns.catplot(x="Gender", y="Age", 
            data=survey_data, kind="box")

# Show plot
plt.show()

# %%
mpg = pd.read_csv('mpg.csv')

# %% [markdown]
# ## FacetGrids vs. AxesSubplots
#
# Identify what type of object plot g is and assign it to the variable type_of_g.

# %%
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Identify plot type
type_of_g = ____

# Print type
print(type_of_g)
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %% [markdown]
# ## Adding a title to a FacetGrid object
#
# Add the following title to this plot: "Car Weight vs. Horsepower".
#
# **HINT!**
#
# To add a title to a FacetGrid object g, use g.fig.suptitle().

# %%
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Add a title "Car Weight vs. Horsepower"


# Show plot
plt.show()

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  ...  model_year  origin                       name
# 0  18.0          8         307.0  ...          70     usa  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...          70     usa          buick skylark 320
# 2  18.0          8         318.0  ...          70     usa         plymouth satellite
# 3  16.0          8         304.0  ...          70     usa              amc rebel sst
# 4  17.0          8         302.0  ...          70     usa                ford torino
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Adding a title and axis labels
#
# 1. Add the following title to the plot: "Average MPG Over Time".
# 2. Label the x-axis as "Car Model Year" and the y-axis as "Average MPG".
#
# **HINT!**
#
# Use g.set() with the xlabel and ylabel parameters.

# %%
# Create line plot
g = sns.lineplot(x="model_year", y="mpg_mean", 
                 data=mpg_mean,
                 hue="origin")

# Add a title "Average MPG Over Time"

# Add x-axis and y-axis labels

# Show plot
plt.show()

# %% [markdown]
# ## Rotating x-tick labels
#
# Rotate the x-tick labels 90 degrees.
#
# **HINT!**
#
# Use plt.xticks() and the rotation parameter to rotate the x-tick labels.

# %%
# Create point plot
sns.catplot(x="origin", 
            y="acceleration", 
            data=mpg, 
            kind="point", 
            join=False, 
            capsize=0.1)

# Rotate x-tick labels


# Show plot
plt.show()

# %% [markdown]
# Create new column on survey_data "Interested in Pets" with condition if "Pets" > mean then fill in column True else False
#
# HINT!
#
# Use np.where function

# %%
survey_data["Interested in Pets"] = ___
survey_data["Interested in Pets"].head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Interested in Pets, dtype: bool

# %% [markdown]
# ## Box plot with subgroups
#
# 1. Set the color palette to "Blues".
# 2. Add subgroups to color the box plots based on "Interested in Pets".
# 3. Set the title of the FacetGrid object g to "Age of Those Interested in Pets vs. Not".
# 4. Make the plot display using a Matplotlib function.
#
# **HINT!**
#
# * Use sns.set_palette() to set the color palette.
# * Use the hue parameter in catplot() to create different colored subgroups.
# * To add a title to a FacetGrid object g, use g.fig.suptitle().
# * Use Matplotlib's show() to display the plot.

# %%
# Set palette to "Blues"
____

# Adjust to add subgroups based on "Interested in Pets"
g = sns.catplot(x="Gender",
                y="Age", data=survey_data, 
                kind="box", hue=____)

# Set title to "Age of Those Interested in Pets vs. Not"
____

# Show plot
plt.____

# %% [markdown]
# Create new column on survey_data "Likes Techno" with condition if "Techno" > mean then fill in column True else False
#
# HINT!
#
# Use np.where function

# %%
survey_data["Likes Techno"] = ___
survey_data["Likes Techno"].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Likes Techno, dtype: bool

# %% [markdown]
# 1. Set the figure style to "dark".
# 2. Adjust the bar plot code to add subplots based on "Gender", arranged in columns.
# 3. Add the title "Percentage of Young People Who Like Techno" to this FacetGrid plot.
# 4. Label the x-axis "Location of Residence" and y-axis "% Who Like Techno".
#
# **HINT!**
#
# * Use sns.set_style() to set the figure style.
# * Use the col parameter in catplot() to add subplots arranged in columns.
# * To add a title to a FacetGrid object g, use g.fig.suptitle().
# * To label the x- and y-axis, use the set() function with the xlabel and ylabel parameters.

# %%
# Set the figure style to "dark"
____

# Adjust to add subplots per gender
g = sns.catplot(x="Village - town", y="Likes Techno", 
                data=survey_data, kind="bar",
                ____)

# Add title and axis labels
g.____("Percentage of Young People Who Like Techno", y=1.02)
g.____(____="Location of Residence", 
       ____="% Who Like Techno")

# Show plot
plt.show()
